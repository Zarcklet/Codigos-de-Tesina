# %% [markdown]
# **Tareas pendientes**
# - Cambiar tamaño de los ejes, títulos, la paleta de colores de los gráficos
# - En la matriz de correlación poner la variable categórica
# - Preguntar sobre el score óptimo
# - Preguntar sobre el sobremuestreo
# - Preguntar sobre los valores aleatorios
# - Preguntar sobre la curva roc

# %% [markdown]
# #**Conectarse a Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**Librerías**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from time import time
import matplotlib.colors
import matplotlib.patches as patches

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import (classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, auc,
                             ConfusionMatrixDisplay, f1_score, precision_recall_curve, recall_score, precision_score)
from sklearn.feature_selection import SelectKBest, f_classif, VarianceThreshold, chi2, mutual_info_classif
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import scipy
from collections import Counter

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC  
from xgboost import XGBClassifier
from sklearn.decomposition import PCA

# %% [markdown]
# #**Base de datos**

# %% [markdown]
# ##Lectura de base de datos
#
# La columna **fetal_health** tiene como etiquetas 1-Normal, 2-Sospechoso y 3-Patológico.

# %%
# Lectura de la base de datos

base = pd.read_csv('/content/drive/MyDrive/Proyecto de Consultoria/fetal_health.csv')
print('La base de datos tiene', base.shape[0], 'filas y', base.shape[1], 'columnas')
base.reset_index()
base['fetal_health'] = base['fetal_health'].replace({1:0, 2:1, 3:2})
base.head()
# Out:
# La base de datos tiene 2126 filas y 22 columnas
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           1.0
# 1                 0.0           0.0
# 2                 0.0           0.0
# 3                 1.0           0.0
# 4                 1.0           0.0
#
# [5 rows x 22 columns]

# %%
# Nombre de las columnas

base.columns
# Out:
# Index(['baseline value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %%
# Cambio de nombre a las columnas

base.columns = ['baseline_value', 'accelerations', 'fetal_movement',
                'uterine_contractions', 'light_decelerations', 'severe_decelerations',
                'prolongued_decelerations', 'abnormal_short_tv',
                'mean_value_of_short_tv',
                'percentage_of_time_waltv',
                'mean_value_of_long_tv', 'histogram_width',
                'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
                'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
                'histogram_median', 'histogram_variance', 'histogram_tendency',
                'fetal_health']

aux = base.copy()
base_MRD = base.copy()

# %%
# Conversión de la columna fetal_health a categoríca

base['fetal_health'] = base['fetal_health'].astype('category')

# %%
# Comprobar si hay valores nulos e información de las columnas

# Verifica si hay nulos en la base
#base.isnull().any()

# Suma la cantidad de nulos que hay en la base
base.isnull().sum()
# Out:
# baseline_value                0
# accelerations                 0
# fetal_movement                0
# uterine_contractions          0
# light_decelerations           0
# severe_decelerations          0
# prolongued_decelerations      0
# abnormal_short_tv             0
# mean_value_of_short_tv        0
# percentage_of_time_waltv      0
# mean_value_of_long_tv         0
# histogram_width               0
# histogram_min                 0
# histogram_max                 0
# histogram_number_of_peaks     0
# histogram_number_of_zeroes    0
# histogram_mode                0
# histogram_mean                0
# histogram_median              0
# histogram_variance            0
# histogram_tendency            0
# fetal_health                  0
# dtype: int64

# %%
# Información de la base

base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   baseline_value              2126 non-null   float64
#  1   accelerations               2126 non-null   float64
#  2   fetal_movement              2126 non-null   float64
#  3   uterine_contractions        2126 non-null   float64
#  4   light_decelerations         2126 non-null   float64
#  5   severe_decelerations        2126 non-null   float64
#  6   prolongued_decelerations    2126 non-null   float64
#  7   abnormal_short_tv           2126 non-null   float64
#  8   mean_value_of_short_tv      2126 non-null   float64
#  9   percentage_of_time_waltv    2126 non-null   float64
#  10  mean_value_of_long_tv       2126 non-null   float64
#  11  histogram_width             2126 non-null   float64
#  12  histogram_min               2126 non-null   float64
#  13  histogram_max               2126 non-null   float64
#  14  histogram_number_of_peaks   2126 non-null   float64
#  15  histogram_number_of_zeroes  2126 non-null   float64
#  16  histogram_mode              2126 non-null   float64
#  17  histogram_mean              2126 non-null   float64
#  18  histogram_median            2126 non-null   float64
#  19  histogram_variance          2126 non-null   float64
#  20  histogram_tendency          2126 non-null   float64
#  21  fetal_health                2126 non-null   category
# dtypes: category(1), float64(21)
# memory usage: 351.1 KB

# %% [markdown]
# #Preprocesamiento

# %% [markdown]
# ##Variables de baja varianza

# %%
# Varianza de cada una de las variables

round(np.var(base.iloc[:, :-1]), 2)
# Out:
# baseline_value                  96.80
# accelerations                    0.00
# fetal_movement                   0.00
# uterine_contractions             0.00
# light_decelerations              0.00
# severe_decelerations             0.00
# prolongued_decelerations         0.00
# abnormal_short_tv              295.45
# mean_value_of_short_tv           0.78
# percentage_of_time_waltv       338.29
# mean_value_of_long_tv           31.66
# histogram_width               1516.83
# histogram_min                  873.40
# histogram_max                  321.84
# histogram_number_of_peaks        8.69
# histogram_number_of_zeroes       0.50
# histogram_mode                 268.22
# histogram_mean                 243.05
# histogram_median               209.18
# histogram_variance             839.31
# histogram_tendency               0.37
# dtype: float64

# %%
# Da como resultado aquellas variables que estan por debajo de 0.25 de varianza

varianza = VarianceThreshold(threshold = 1)
varianza.fit(base.iloc[:, :-1])
columnas = [i for i in base.iloc[:, :-1].columns if i not in base.iloc[:, :-1].columns[varianza.get_support()]]
columnas
# Out:
# ['accelerations',
#  'fetal_movement',
#  'uterine_contractions',
#  'light_decelerations',
#  'severe_decelerations',
#  'prolongued_decelerations',
#  'mean_value_of_short_tv',
#  'histogram_number_of_zeroes',
#  'histogram_tendency']

# %%
# Nueva base de datos sin las variables con baja varianza

base = base.drop(columnas, axis = 1)
print('La base de datos tiene', base.shape[0], 'filas y', base.shape[1], 'columnas')
# Out:
# La base de datos tiene 2126 filas y 13 columnas

# %% [markdown]
# ##Sobremuestreo

# %%
# Conteo de las clases antes del sobremuestreo

ContarA = Counter(base.iloc[:, -1])
print('Antes del sobremuestreo:', ContarA)
# Out:
# Antes del sobremuestreo: Counter({0.0: 1655, 1.0: 295, 2.0: 176})

# %%
# Realizar sobremuestreo con la técnica SMOTEENN

copia_base = base.copy()
filas = base.shape[0]
smoteenn = SMOTEENN(sampling_strategy = 'not majority')
base_smoteenn = smoteenn.fit_resample(copia_base.iloc[:, :-1], copia_base.iloc[:, -1])
                                                             
base_sobremuestreo = base_smoteenn[0]
base_sobremuestreo['fetal_health'] = base_smoteenn[1]
                                                             
print('Se agregarón', base_sobremuestreo.shape[0] - filas, 'filas con respecto a las clases minoritarias')
# Out:
# Se agregarón 2446 filas con respecto a las clases minoritarias

# %%
# Conteo de clases después del sobremuestreo

ContarD = Counter(base_sobremuestreo.iloc[:, -1])
print('Después del sobremuestreo:', ContarD)
# Out:
# Después del sobremuestreo: Counter({2.0: 1611, 1.0: 1560, 0.0: 1401})

# %%
# Realiza un gráfico de conteo de las clases de la variable fetal_health

sns.set_style('darkgrid')
sns.color_palette('husl', 9)

plt.figure(figsize = (10, 5))
colores = {0: 'blue', 1: 'orange', 2: 'red'}

a = sns.countplot(x = base_sobremuestreo['fetal_health'],
                  order = base_sobremuestreo['fetal_health'].value_counts(ascending = False).index, edgecolor = 'black',
                  palette = colores, alpha = 0.5)
valores_absolutos = base_sobremuestreo['fetal_health'].value_counts(ascending = False)
valores_relativos = base_sobremuestreo['fetal_health'].value_counts(ascending = False, normalize = True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(valores_absolutos, valores_relativos)]

a.bar_label(container = a.containers[0], labels = lbls, fontweight = 'bold',
            label_type = 'center',
            #padding = 10,
            color = 'black',
            fontsize = 12)
a.set_xticklabels(['Patológico', 'Sospechoso', 'Normal'])

plt.suptitle('Conteo de las clases de la variable fetal_health', fontweight = 'bold', fontsize = 25, color = 'black')
plt.xticks(color = 'black', fontsize = 12)
plt.yticks(color = 'black')
plt.xlabel('Salud fetal', fontweight = 'bold', fontsize = 15, color = 'black', labelpad = 10)
plt.ylabel('Conteo', fontweight = 'bold', fontsize = 15, color = 'black')
plt.subplots_adjust(top = 0.88)

# %% [markdown]
# ##Selección de variables más importantes

# %% [markdown]
# ###Base de datos desequilibrada

# %%
# Realiza la selección de variables de la base desequilibrada
#https://enjoymachinelearning.com/blog/feature-selection-selectkbest-sklearn/

x = base.iloc[:, :-1] 
y = base.iloc[:, -1]

seleccion = SelectKBest(f_classif, k = 'all')
seleccion.fit(x,y)

puntajes = pd.DataFrame(seleccion.scores_)
columnas = pd.DataFrame(x.columns)
variables_puntaje = pd.concat([columnas, puntajes], axis = 1)
variables_puntaje.columns = ['Variables', 'Puntaje'] 

plt.subplots(figsize = (10, 5))
sns.barplot(data = variables_puntaje, x = 'Puntaje', y = 'Variables', edgecolor = 'black',
            saturation = 1, orient = 'h', alpha = 0.5, palette = 'YlGnBu')
plt.vlines(x = 100, ymin = -1, ymax = 12, color = 'red')
plt.suptitle('Base de datos desequilibrada', fontweight = 'bold', fontsize = 25, color = 'black')
plt.subplots_adjust(top = 0.88)
plt.xticks(color = 'black', fontsize = 12)
plt.yticks(color = 'black', fontsize = 12)
plt.xlabel('Puntaje', fontweight = 'bold', fontsize = 16, color = 'black', labelpad = 10)
plt.ylabel('Variables', fontweight = 'bold', fontsize = 16, color = 'black')
# Out:
# Text(0, 0.5, 'Variables')

# %%
# Crea la nueva base de datos con las variables seleccionadas de la base desequilibrada

seleccionarva = variables_puntaje[variables_puntaje['Puntaje'] >= 100] 
seleccionarva = list(seleccionarva['Variables']) 
seleccionarva.append('fetal_health') 

base_nueva = base[seleccionarva]

print('La base de datos desequilibrada nueva tiene', base_nueva.shape[0], 'filas y', base_nueva.shape[1], 'columnas')
# Out:
# La base de datos desequilibrada nueva tiene 2126 filas y 8 columnas

# %% [markdown]
# ###Base de datos equilibrada

# %%
# Realiza la selección de variables de la base equilibrada

x = base_sobremuestreo.iloc[:, :-1] 
y = base_sobremuestreo.iloc[:, -1]

seleccion = SelectKBest(f_classif, k = 'all')
seleccion.fit(x,y)

puntajes = pd.DataFrame(seleccion.scores_)
columnas = pd.DataFrame(x.columns)
variables_puntaje = pd.concat([columnas, puntajes], axis = 1)
variables_puntaje.columns = ['Variables', 'Puntaje'] 

plt.subplots(figsize = (10, 5))
sns.barplot(data = variables_puntaje, x = 'Puntaje', y = 'Variables', edgecolor = 'black',
            saturation = 1, orient = 'h', alpha = 0.5, palette = 'YlGnBu')
plt.vlines(x = 500, ymin = -1, ymax = 12, color = 'red')
plt.suptitle('Base de datos equilibrada', fontweight = 'bold', fontsize = 25, color = 'black')
plt.subplots_adjust(top = 0.88)
plt.xticks(color = 'black', fontsize = 12)
plt.yticks(color = 'black', fontsize = 12)
plt.xlabel('Puntaje', fontweight = 'bold', fontsize = 16, color = 'black', labelpad = 10)
plt.ylabel('Variables', fontweight = 'bold', fontsize = 16, color = 'black')
# Out:
# Text(0, 0.5, 'Variables')

# %%
# Crea la nueva base de datos con las variables seleccionadas de la base equilibrada

seleccionarva = variables_puntaje[variables_puntaje['Puntaje'] >= 500] 
seleccionarva = list(seleccionarva['Variables']) 
seleccionarva.append('fetal_health') 

base_nueva_sobremuestreo = base_sobremuestreo[seleccionarva]

print('La base de datos equilibrada nueva tiene', base_nueva_sobremuestreo.shape[0], 'filas y',
      base_nueva_sobremuestreo.shape[1], 'columnas')
# Out:
# La base de datos equilibrada nueva tiene 4572 filas y 10 columnas

# %% [markdown]
# #Aprendizaje Supervisado

# %% [markdown]
# ##Base de datos desequilibrada

# %% [markdown]
# ###División del conjunto de entrenamiento y prueba

# %%
# Separa la base desequilibrada en entrenamiento y prueba

x_entrena, x_prueba, y_entrena, y_prueba = train_test_split(base_nueva.iloc[:, :-1], base_nueva.iloc[:, -1],
                                                            test_size = 0.3, shuffle = True)
print('La base de datos desequilibrada de entrenamiento tiene', x_entrena.shape[0], 'filas y', x_entrena.shape[1], 'columnas')
print('La base de datos desequilibrada de prueba tiene', x_prueba.shape[0], 'filas y', x_prueba.shape[1], 'columnas')
# Out:
# La base de datos desequilibrada de entrenamiento tiene 1488 filas y 7 columnas
# La base de datos desequilibrada de prueba tiene 638 filas y 7 columnas

# %% [markdown]
# ###Estandarización de los conjuntos de datos

# %%
# Estandariza la base desequilibrada

estandarizar = StandardScaler()
x_entrena = estandarizar.fit_transform(x_entrena) 
x_prueba = estandarizar.transform(x_prueba)

# %% [markdown]
# ###Modelo XGBoost

# %% [markdown]
# ###Entrenamiento, prueba del modelo y reporte de resultados

# %%
# Función para crear una matriz de confusión

#colores = matplotlib.colors.LinearSegmentedColormap.from_list('custom', ['#008B8B', '#E0FFFF', '#FFFFFF'])
#YlGnBu

etiquetas = ['Normal', 'Sospechoso', 'Patológico']

def matriz_confusion(y_prueba, y_predicha):
  conf_mat = confusion_matrix(y_prueba, y_predicha)
  fig, ax = plt.subplots(figsize = (8,6))
  sns.heatmap(conf_mat, annot = True, fmt = 'd',
              xticklabels = etiquetas,
              yticklabels = etiquetas, cmap = 'Blues',
              linecolor = 'black')
  plt.title('Matriz de Confusión', fontweight = 'bold')
  plt.xlabel('Valores predichos', fontweight = 'bold')
  plt.ylabel('Valores reales', fontweight = 'bold')
  plt.show()

# %%
# Evalua el modelo KNN con parámetros predeterminados

xgb = XGBClassifier()
xgb.fit(x_entrena, y_entrena)
y_predicha = xgb.predict(x_prueba)
print('Exactitud en la base de datos desequilibrada:', str(round((cross_val_score(xgb, x_entrena, y_entrena, cv = 10)).mean()*100, 4)) + '%')
print(classification_report(y_prueba, y_predicha, target_names = etiquetas))
matriz_confusion(y_prueba, y_predicha)
# Out:
# Exactitud en la base de datos desequilibrada: 93.548%
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.98      0.97       498
#   Sospechoso       0.83      0.81      0.82        86
#   Patológico       0.94      0.83      0.88        54
#
#     accuracy                           0.94       638
#    macro avg       0.91      0.88      0.89       638
# weighted avg       0.94      0.94      0.94       638

# %% [markdown]
# ###Hiperparámetros: Entrenamiento, prueba del modelo y reporte de resultados

# %%
# Selección de los hiperparámetros de manera aleatoria

#https://jdvelasq.github.io/courses/notebooks/sklearn_model_selection_and_evaluation/1-09_RandomizedSearchCV.html
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/

#scipy.stats.uniform(scale = 1).rvs(size = 1000)
#scipy.stats.randint.rvs(low = 1, high = 100, size=1000)
#scipy.stats.randint.rvs(low = 1, high = 100, size=10)
#sampling_method no admite gradient_based

subsample = np.append(scipy.stats.uniform(scale = 1).rvs(size = 100), 0.5)
gamma = np.append(scipy.stats.uniform(scale = 1).rvs(size = 100), [1, 10, 50, 100])
lambda1 = np.append(scipy.stats.uniform(scale = 1).rvs(size = 100), [1, 10, 50, 100])
alpha1 = np.append(scipy.stats.uniform(scale = 1).rvs(size = 100), [1, 10, 50, 100])
eta = np.append(scipy.stats.uniform(scale = 0.1).rvs(size = 100), [0, 1])
rate_drop = np.append(scipy.stats.uniform(scale = 1).rvs(size = 20), [0, 1])

parametros = {
    'booster': ['gbtree', 'gblinear', 'dart'],
    'validate_parameters': [True],
    'gamma': gamma,
    'max_depth': scipy.stats.randint.rvs(low = 1, high = 101, size = 100),
    'eta': eta,
    'n_estimators': scipy.stats.randint.rvs(low = 100, high = 1001, size = 100),
    #'sampling_method': ['uniform'],
    'subsample': subsample,
    #'tree_method': ['auto', 'exact', 'approx', 'hist', 'gpu_hist'],
    'max_delta_step': scipy.stats.randint.rvs(low = 0, high = 21, size = 20),
    'min_child_weight': scipy.stats.randint.rvs(low = 0, high = 21, size = 20),
    'lambda': lambda1,
    'alpha': alpha1,
    'normalize_type': ['tree', 'forest'],
    'sample_type': ['uniform', 'weighted'],
    'rate_drop': rate_drop
}

# %%
# Entrenamiento del modelo

hiperparametros = RandomizedSearchCV(estimator = XGBClassifier(),
                                     param_distributions = parametros,
                                     n_iter = 10,
                                     cv = 10,
                                     scoring= 'accuracy',
                                     refit = True,
                                     #n_jobs = -1,
                                     return_train_score = True,
                                     verbose = 3)

start = time()
hiperparametros.fit(x_entrena, y_entrena)
print('\n')
print('Le tomó %.2f segundos para encontrar los parámetros'%(time() - start))
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [00:54:35] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 1/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.923, test=0.899) total time=   0.5s
# [00:54:36] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 2/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.919, test=0.899) total time=   0.5s
# [00:54:36] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 3/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.922, test=0.893) total time=   0.5s
# [00:54:37] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 4/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.919, test=0.940) total time=   0.5s
# [00:54:37] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 5/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.920, test=0.879) total time=   0.5s
# [00:54:38] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 6/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.921, test=0.913) total time=   0.5s
# [00:54:38] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 7/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.916, test=0.919) total time=   0.5s
# [00:54:39] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 8/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.922, test=0.879) total time=   0.5s
# [00:54:39] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 9/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.915, test=0.926) total time=   0.5s
# [00:54:40] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 10/10] END alpha=0.7410225922295529, booster=gbtree, eta=0.05087230150448673, gamma=0.962739416643182, lambda=0.44448594538471253, max_delta_step=13, max_depth=59, min_child_weight=16, n_estimators=384, normalize_type=forest, sample_type=weighted, subsample=0.36455287653270807, validate_parameters=True;, score=(train=0.921, test=0.905) total time=   0.5s
# [CV 1/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.987, test=0.933) total time= 1.4min
# [CV 2/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.986, test=0.946) total time= 1.3min
# [CV 3/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.987, test=0.913) total time= 1.3min
# [CV 4/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.983, test=0.960) total time= 1.3min
# [CV 5/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.984, test=0.926) total time= 1.3min
# [CV 6/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.983, test=0.940) total time= 1.3min
# [CV 7/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.985, test=0.946) total time= 1.3min
# [CV 8/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.986, test=0.893) total time= 1.2min
# [CV 9/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.988, test=0.939) total time= 1.3min
# [CV 10/10] END alpha=0.48109178087076265, booster=dart, eta=0.02233892035712558, gamma=0.9035196164297392, lambda=0.6294573133374292, max_delta_step=3, max_depth=20, min_child_weight=0, n_estimators=922, normalize_type=forest, sample_type=weighted, subsample=0.8372777337342994, validate_parameters=True;, score=(train=0.987, test=0.939) total time= 1.3min
# [01:07:47] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 1/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.942, test=0.919) total time=   1.4s
# [01:07:48] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 2/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.940, test=0.940) total time=   1.4s
# [01:07:50] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 3/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.948, test=0.899) total time=   1.4s
# [01:07:51] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 4/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.945, test=0.960) total time=   1.5s
# [01:07:53] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 5/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.944, test=0.906) total time=   3.8s
# [01:07:56] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 6/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.940, test=0.913) total time=   1.4s
# [01:07:58] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 7/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.945, test=0.926) total time=   1.4s
# [01:07:59] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 8/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.947, test=0.893) total time=   1.4s
# [01:08:01] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 9/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.946, test=0.939) total time=   1.4s
# [01:08:02] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 10/10] END alpha=0.6788770932693818, booster=gbtree, eta=0.023292152174665792, gamma=0.9155274803077935, lambda=50.0, max_delta_step=14, max_depth=97, min_child_weight=2, n_estimators=474, normalize_type=tree, sample_type=uniform, subsample=0.8773114712867028, validate_parameters=True;, score=(train=0.947, test=0.919) total time=   1.4s
# [01:08:04] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 1/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.992, test=0.933) total time=   2.8s
# [01:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 2/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.990, test=0.946) total time=   4.7s
# [01:08:11] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 3/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.993, test=0.913) total time=   2.5s
# [01:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 4/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.990, test=0.960) total time=   2.6s
# [01:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 5/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.989, test=0.926) total time=   2.6s
# [01:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 6/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.993, test=0.933) total time=   4.9s
# [01:08:24] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 7/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.993, test=0.953) total time=   2.6s
# [01:08:27] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 8/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.990, test=0.913) total time=   2.5s
# [01:08:29] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 9/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.992, test=0.926) total time=   3.4s
# [01:08:33] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 10/10] END alpha=0.23451596064360392, booster=gbtree, eta=0.0691443656663007, gamma=0.8258939963857768, lambda=0.21180681268944967, max_delta_step=8, max_depth=13, min_child_weight=2, n_estimators=721, normalize_type=tree, sample_type=weighted, subsample=0.9232028629992077, validate_parameters=True;, score=(train=0.992, test=0.939) total time=   4.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 1/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 2/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 3/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 4/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 5/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 6/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 7/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 8/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.778, test=0.772) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 9/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.778, test=0.777) total time=   0.1s
# [01:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 10/10] END alpha=0.690705116856039, booster=gblinear, eta=0.06123840816600068, gamma=0.20245871854818187, lambda=0.6584675788539495, max_delta_step=15, max_depth=64, min_child_weight=2, n_estimators=216, normalize_type=forest, sample_type=uniform, subsample=0.8261130265121834, validate_parameters=True;, score=(train=0.778, test=0.777) total time=   0.1s
# [01:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 1/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.943, test=0.919) total time=   1.4s
# [01:08:39] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 2/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.934, test=0.913) total time=   1.4s
# [01:08:40] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 3/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.940, test=0.893) total time=   1.3s
# [01:08:42] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 4/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.937, test=0.946) total time=   1.4s
# [01:08:43] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 5/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.942, test=0.899) total time=   3.8s
# [01:08:47] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 6/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.940, test=0.919) total time=   1.4s
# [01:08:48] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 7/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.937, test=0.940) total time=   1.4s
# [01:08:50] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 8/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.942, test=0.893) total time=   1.4s
# [01:08:51] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 9/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.936, test=0.946) total time=   1.4s
# [01:08:53] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 10/10] END alpha=0.2601150725971736, booster=gbtree, eta=0.027100031770271416, gamma=0.9035196164297392, lambda=0.5419452793653557, max_delta_step=9, max_depth=91, min_child_weight=12, n_estimators=949, normalize_type=forest, sample_type=uniform, subsample=0.418156071351666, validate_parameters=True;, score=(train=0.938, test=0.905) total time=   1.4s
# [01:08:54] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 1/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.3s
# [01:08:54] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 2/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.3s
# [01:08:55] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 3/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.2s
# [01:08:55] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 4/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.2s
# [01:08:55] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 5/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.3s
# [01:08:56] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 6/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.2s
# [01:08:56] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 7/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.3s
# [01:08:56] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 8/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.778, test=0.772) total time=   0.2s
# [01:08:56] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 9/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.778, test=0.777) total time=   0.3s
# [01:08:57] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 10/10] END alpha=0.11242672893519512, booster=gblinear, eta=0.08919909237427529, gamma=0.5464606394733236, lambda=0.21626162537029114, max_delta_step=15, max_depth=97, min_child_weight=2, n_estimators=669, normalize_type=forest, sample_type=weighted, subsample=0.7833080875523267, validate_parameters=True;, score=(train=0.778, test=0.777) total time=   0.3s
# [CV 1/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.954, test=0.933) total time=   3.2s
# [CV 2/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.954, test=0.926) total time=   1.0s
# [CV 3/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.954, test=0.886) total time=   1.0s
# [CV 4/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.954, test=0.960) total time=   1.0s
# [CV 5/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.953, test=0.906) total time=   1.0s
# [CV 6/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.950, test=0.940) total time=   1.0s
# [CV 7/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.952, test=0.960) total time=   1.0s
# [CV 8/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.959, test=0.886) total time=   0.9s
# [CV 9/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.953, test=0.946) total time=   1.0s
# [CV 10/10] END alpha=0.20438030520024353, booster=dart, eta=0.0691443656663007, gamma=0.614567149413204, lambda=0.04949688833156629, max_delta_step=13, max_depth=93, min_child_weight=12, n_estimators=101, normalize_type=tree, sample_type=uniform, subsample=0.8502503438194701, validate_parameters=True;, score=(train=0.953, test=0.939) total time=   1.0s
# [01:09:09] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 1/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:09:09] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 2/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:09:09] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 3/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.1s
# [01:09:10] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 4/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.2s
# [01:09:10] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 5/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   0.2s
# [01:09:10] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 6/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   1.0s
# [01:09:11] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 7/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.777, test=0.779) total time=   1.2s
# [01:09:12] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 8/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.778, test=0.772) total time=   0.3s
# [01:09:13] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 9/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.778, test=0.777) total time=   0.1s
# [01:09:13] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 10/10] END alpha=0.8454766614881334, booster=gblinear, eta=0.07441931320058269, gamma=0.3295381208751733, lambda=0.5312681713374084, max_delta_step=9, max_depth=65, min_child_weight=20, n_estimators=324, normalize_type=tree, sample_type=weighted, subsample=0.1454820240477026, validate_parameters=True;, score=(train=0.778, test=0.777) total time=   0.1s
# [CV 1/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.907, test=0.893) total time=   2.4s
# [CV 2/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.913, test=0.893) total time=   2.4s
# [CV 3/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.916, test=0.893) total time=   2.4s
# [CV 4/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.904, test=0.946) total time=   2.7s
# [CV 5/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.915, test=0.886) total time=   3.6s
# [CV 6/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.911, test=0.893) total time=   2.4s
# [CV 7/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.910, test=0.906) total time=   2.4s
# [CV 8/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.909, test=0.886) total time=   2.4s
# [CV 9/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.911, test=0.919) total time=   4.8s
# [CV 10/10] END alpha=0.6788770932693818, booster=dart, eta=0.017525791562601766, gamma=0.18491088468356975, lambda=0.025707221361308763, max_delta_step=9, max_depth=100, min_child_weight=16, n_estimators=175, normalize_type=tree, sample_type=weighted, subsample=0.4826593666457838, validate_parameters=True;, score=(train=0.918, test=0.905) total time=   2.4s
# [01:09:42] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
#
#
# Le tomó 910.40 segundos para encontrar los parámetros

# %%
# Resultados del entrenamiento

print('Los mejores parámetros para la base de datos desequilibrada:', hiperparametros.best_params_)
print('\n')
print('Índice que le corresponde:', hiperparametros.best_index_)
print('\n')
print('Mejor estimador:', hiperparametros.best_estimator_)
print('\n')
print('Mejor exactitud:', str(round(hiperparametros.best_score_*100, 4)) + '%')
# Out:
# Los mejores parámetros para la base de datos desequilibrada: {'validate_parameters': True, 'subsample': 0.9232028629992077, 'sample_type': 'weighted', 'normalize_type': 'tree', 'n_estimators': 721, 'min_child_weight': 2, 'max_depth': 13, 'max_delta_step': 8, 'lambda': 0.21180681268944967, 'gamma': 0.8258939963857768, 'eta': 0.0691443656663007, 'booster': 'gbtree', 'alpha': 0.23451596064360392}
#
#
# Índice que le corresponde: 3
#
#
# Mejor estimador: XGBClassifier(alpha=0.23451596064360392, base_score=None, booster='gbtree',
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.0691443656663007,
#               eval_metric=None, feature_types=None, gamma=0.8258939963857768,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, lambda=0.21180681268944967,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=8, max_depth=13,
#               max_leaves=None, min_child_weight=2, missing=nan,
#               monotone_constraints=None, n_estimators=721, n_jobs=None, ...)
#
#
# Mejor exactitud: 93.4137%

# %%
# Evaluación del modelo

y_predicha = hiperparametros.predict(x_prueba)
print(classification_report(y_prueba, y_predicha, target_names = etiquetas))
matriz_confusion(y_prueba, y_predicha)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.97      0.96       498
#   Sospechoso       0.79      0.76      0.77        86
#   Patológico       0.96      0.83      0.89        54
#
#     accuracy                           0.93       638
#    macro avg       0.90      0.85      0.87       638
# weighted avg       0.93      0.93      0.93       638

# %%
# Curva ROC AUC

etiquetas_clases= ['Normal', 'Sospechoso', 'Patológico']
colores = ['darkgreen', 'darkorange', 'darkred']

# Función para calcular el ROC AUC multiclase (con gráfico)
def multiclass_roc_auc_score(y_prueba, y_predicha, average = 'weighted'):
    lb = LabelBinarizer()
    lb.fit(y_prueba)
    y_prueba = lb.transform(y_prueba)
    y_predicha = lb.transform(y_predicha)

    plt.subplots(1,1, figsize = (8, 5))
    for (idx, c_label) in enumerate(etiquetas_clases):
        fpr, tpr, thresholds = roc_curve(y_prueba[:, idx].astype(int), y_predicha[:,idx])
        plt.plot(fpr, tpr, label = '%s (AUC: %0.2f)' % (c_label, auc(fpr, tpr)), color = colores[idx])
    plt.plot(fpr, fpr, linestyle = '--', color = 'black')
    plt.legend()
    plt.title('Gráfico de curva ROC', fontweight = 'bold')
    plt.xlabel('Tasa de Falsos Positivos', fontweight = 'bold')
    plt.ylabel('Tasa de Verdaderos Positivos', fontweight = 'bold')
    plt.show()
    return roc_auc_score(y_prueba, y_predicha, average = average)

print(f'Área bajo la curva: {multiclass_roc_auc_score(y_prueba, y_predicha)*100:.4f}%\n')
# Out:
# Área bajo la curva: 89.0032%

# %%
# Tabla de resultados de hiperparámetros

tabla = pd.DataFrame(hiperparametros.cv_results_).head(3)
tabla
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.508400      0.013933         0.004575        0.001544
# 1      77.897996      2.508786         0.087166        0.040935
# 2       1.646426      0.722375         0.005262        0.000205
#
#   param_validate_parameters param_subsample param_sample_type  \
# 0                      True        0.364553          weighted
# 1                      True        0.837278          weighted
# 2                      True        0.877311           uniform
#
#   param_normalize_type param_n_estimators param_min_child_weight  ...  \
# 0               forest                384                     16  ...
# 1               forest                922                      0  ...
# 2                 tree                474                      2  ...
#
#   split2_train_score split3_train_score split4_train_score split5_train_score  \
# 0           0.921583           0.918596           0.920090           0.920836
# 1           0.987304           0.982823           0.984317           0.982823
# 2           0.947722           0.944735           0.943988           0.940254
#
#   split6_train_score split7_train_score split8_train_score split9_train_score  \
# 0           0.915609           0.921583           0.914925           0.920896
# 1           0.985063           0.985810           0.988060           0.986567
# 2           0.944735           0.946975           0.945522           0.947015
#
#    mean_train_score  std_train_score
# 0          0.919654         0.002495
# 1          0.985513         0.001679
# 2          0.944220         0.002720
#
# [3 rows x 43 columns]

# %% [markdown]
# ##Base de datos equilibrada

# %% [markdown]
# ###División del conjunto de entrenamiento y prueba

# %%
# Separa la base desequilibrada en entrenamiento y prueba

x_entrena, x_prueba, y_entrena, y_prueba = train_test_split(base_nueva_sobremuestreo.iloc[:, :-1], base_nueva_sobremuestreo.iloc[:, -1],
                                                            test_size = 0.3, shuffle = True)
print('La base de datos desequilibrada de entrenamiento tiene', x_entrena.shape[0], 'filas y', x_entrena.shape[1], 'columnas')
print('La base de datos desequilibrada de prueba tiene', x_prueba.shape[0], 'filas y', x_prueba.shape[1], 'columnas')
# Out:
# La base de datos desequilibrada de entrenamiento tiene 3200 filas y 9 columnas
# La base de datos desequilibrada de prueba tiene 1372 filas y 9 columnas

# %% [markdown]
# ###Estandarización de los conjuntos de datos

# %%
# Estandariza la base desequilibrada

estandarizar = StandardScaler()
x_entrena = estandarizar.fit_transform(x_entrena) 
x_prueba = estandarizar.transform(x_prueba)

# %% [markdown]
# ###Modelo XGBoost

# %% [markdown]
# ###Entrenamiento, prueba del modelo y reporte de resultados

# %%
# Función para crear una matriz de confusión

#colores = matplotlib.colors.LinearSegmentedColormap.from_list('custom', ['#008B8B', '#E0FFFF', '#FFFFFF'])
#YlGnBu

etiquetas = ['Normal', 'Sospechoso', 'Patológico']

def matriz_confusion(y_prueba, y_predicha):
  conf_mat = confusion_matrix(y_prueba, y_predicha)
  fig, ax = plt.subplots(figsize = (8,6))
  sns.heatmap(conf_mat, annot = True, fmt = 'd',
              xticklabels = etiquetas,
              yticklabels = etiquetas, cmap = 'Blues',
              linecolor = 'black')
  plt.title('Matriz de Confusión', fontweight = 'bold')
  plt.xlabel('Valores predichos', fontweight = 'bold')
  plt.ylabel('Valores reales', fontweight = 'bold')
  plt.show()

# %%
# Evalua el modelo KNN con parámetros predeterminados

xgb = XGBClassifier()
xgb.fit(x_entrena, y_entrena)
y_predicha = xgb.predict(x_prueba)
print('Exactitud en la base de datos desequilibrada:', str(round((cross_val_score(xgb, x_entrena, y_entrena, cv = 10)).mean()*100, 4)) + '%')
print(classification_report(y_prueba, y_predicha, target_names = etiquetas))
matriz_confusion(y_prueba, y_predicha)
# Out:
# Exactitud en la base de datos desequilibrada: 98.1875%
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.98      0.98       395
#   Sospechoso       0.99      0.98      0.98       474
#   Patológico       0.99      0.99      0.99       503
#
#     accuracy                           0.99      1372
#    macro avg       0.99      0.99      0.99      1372
# weighted avg       0.99      0.99      0.99      1372

# %% [markdown]
# ###Hiperparámetros: Entrenamiento, prueba del modelo y reporte de resultados

# %%
# Selección de los hiperparámetros de manera aleatoria

#https://jdvelasq.github.io/courses/notebooks/sklearn_model_selection_and_evaluation/1-09_RandomizedSearchCV.html
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/

#scipy.stats.uniform(scale = 1).rvs(size = 1000)
#scipy.stats.randint.rvs(low = 1, high = 100, size=1000)
#scipy.stats.randint.rvs(low = 1, high = 100, size=10)
#sampling_method no admite gradient_based

subsample = np.append(scipy.stats.uniform(scale = 1).rvs(size = 100), 0.5)
gamma = np.append(scipy.stats.uniform(scale = 1).rvs(size = 100), [1, 10, 50, 100])
lambda1 = np.append(scipy.stats.uniform(scale = 1).rvs(size = 100), [1, 10, 50, 100])
alpha1 = np.append(scipy.stats.uniform(scale = 1).rvs(size = 100), [1, 10, 50, 100])
eta = np.append(scipy.stats.uniform(scale = 0.1).rvs(size = 100), [0, 1])

parametros = {
    'booster': ['gbtree', 'gblinear', 'dart'],
    'validate_parameters': [True],
    'gamma': gamma,
    'max_depth': scipy.stats.randint.rvs(low = 1, high = 101, size = 100),
    'eta': eta,
    'n_estimators': scipy.stats.randint.rvs(low = 100, high = 1001, size = 100),
    #'sampling_method': ['uniform'],
    'subsample': subsample,
    #'tree_method': ['auto', 'exact', 'approx', 'hist', 'gpu_hist'],
    'max_delta_step': scipy.stats.randint.rvs(low = 0, high = 21, size = 20),
    'min_child_weight': scipy.stats.randint.rvs(low = 0, high = 21, size = 20),
    'lambda': lambda1,
    'alpha': alpha1,
    'normalize_type': ['tree', 'forest'],
    'sample_type': ['uniform', 'weighted']
}

# %%
# Entrenamiento del modelo

hiperparametros = RandomizedSearchCV(estimator = XGBClassifier(),
                                     param_distributions = parametros,
                                     n_iter = 10,
                                     cv = 10,
                                     scoring= 'accuracy',
                                     refit = True,
                                     #n_jobs = -1,
                                     return_train_score = True,
                                     verbose = 3)

start = time()
hiperparametros.fit(x_entrena, y_entrena)
print('\n')
print('Le tomó %.2f segundos para encontrar los parámetros'%(time() - start))
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV 1/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.956, test=0.956) total time=  29.6s
# [CV 2/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.957, test=0.944) total time=  29.5s
# [CV 3/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.956, test=0.953) total time=  29.3s
# [CV 4/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.957, test=0.941) total time=  31.7s
# [CV 5/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.959, test=0.944) total time=  29.6s
# [CV 6/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.958, test=0.941) total time=  31.9s
# [CV 7/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.958, test=0.950) total time=  31.8s
# [CV 8/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.958, test=0.950) total time=  31.4s
# [CV 9/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.959, test=0.938) total time=  29.2s
# [CV 10/10] END alpha=50.0, booster=dart, eta=0.021830121537260796, gamma=0.8202469603939182, lambda=0.5199665001933372, max_delta_step=9, max_depth=82, min_child_weight=3, n_estimators=403, normalize_type=forest, sample_type=weighted, subsample=0.8816435421107098, validate_parameters=True;, score=(train=0.959, test=0.947) total time=  29.5s
# [CV 1/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.987, test=0.984) total time=  20.7s
# [CV 2/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.987, test=0.963) total time=  20.6s
# [CV 3/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.986, test=0.969) total time=  18.6s
# [CV 4/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.986, test=0.978) total time=  20.9s
# [CV 5/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.986, test=0.966) total time=  29.5s
# [CV 6/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.987, test=0.975) total time=  49.5s
# [CV 7/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.987, test=0.972) total time=  18.5s
# [CV 8/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.987, test=0.975) total time=  20.7s
# [CV 9/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.985, test=0.978) total time=  18.5s
# [CV 10/10] END alpha=0.45160088484088023, booster=dart, eta=0.09319264881313054, gamma=0.7531290472820037, lambda=0.33649701448979175, max_delta_step=18, max_depth=100, min_child_weight=18, n_estimators=343, normalize_type=forest, sample_type=weighted, subsample=0.6371468819748921, validate_parameters=True;, score=(train=0.987, test=0.969) total time=  21.5s
# [01:19:09] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 1/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.998, test=0.988) total time=   1.9s
# [01:19:11] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 2/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.997, test=0.969) total time=   1.8s
# [01:19:13] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 3/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.998, test=0.981) total time=   2.0s
# [01:19:15] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 4/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.998, test=0.978) total time=   4.0s
# [01:19:19] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 5/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.998, test=0.978) total time=   1.8s
# [01:19:21] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 6/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.997, test=0.975) total time=   1.9s
# [01:19:23] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 7/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.999, test=0.969) total time=   1.8s
# [01:19:25] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 8/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.998, test=0.981) total time=   1.9s
# [01:19:27] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 9/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.998, test=0.981) total time=   4.7s
# [01:19:32] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 10/10] END alpha=0.3888913417409099, booster=gbtree, eta=0.07677492846285415, gamma=0.31661537038928034, lambda=0.8060132045436814, max_delta_step=9, max_depth=29, min_child_weight=8, n_estimators=297, normalize_type=forest, sample_type=weighted, subsample=0.8452189326526658, validate_parameters=True;, score=(train=0.998, test=0.972) total time=   1.9s
# [CV 1/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.985, test=0.981) total time= 1.4min
# [CV 2/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.987, test=0.963) total time= 1.3min
# [CV 3/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.985, test=0.969) total time= 1.3min
# [CV 4/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.984, test=0.975) total time= 1.3min
# [CV 5/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.984, test=0.963) total time= 1.3min
# [CV 6/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.984, test=0.969) total time= 1.3min
# [CV 7/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.986, test=0.975) total time= 1.4min
# [CV 8/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.984, test=0.972) total time= 1.3min
# [CV 9/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.983, test=0.972) total time= 1.3min
# [CV 10/10] END alpha=0.9782235531977819, booster=dart, eta=0.04314042079694899, gamma=0.9336597492487824, lambda=0.4100847472596517, max_delta_step=16, max_depth=8, min_child_weight=14, n_estimators=709, normalize_type=tree, sample_type=uniform, subsample=0.49950437274697, validate_parameters=True;, score=(train=0.985, test=0.969) total time= 1.4min
# [01:32:57] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 1/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.753, test=0.778) total time=   0.4s
# [01:32:57] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 2/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.755, test=0.756) total time=   0.3s
# [01:32:57] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 3/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.760, test=0.744) total time=   0.4s
# [01:32:58] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 4/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.759, test=0.756) total time=   0.3s
# [01:32:58] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 5/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.755, test=0.778) total time=   0.3s
# [01:32:58] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 6/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.762, test=0.709) total time=   0.3s
# [01:32:59] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 7/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.757, test=0.781) total time=   0.3s
# [01:32:59] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 8/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.753, test=0.772) total time=   0.3s
# [01:32:59] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 9/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.762, test=0.728) total time=   0.3s
# [01:33:00] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 10/10] END alpha=0.06919635221831455, booster=gblinear, eta=0.010483947145172158, gamma=0.45782075849909054, lambda=0.9530468171386962, max_delta_step=12, max_depth=51, min_child_weight=17, n_estimators=409, normalize_type=tree, sample_type=uniform, subsample=0.1621242004652922, validate_parameters=True;, score=(train=0.756, test=0.753) total time=   0.3s
# [01:33:00] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 1/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.347, test=0.344) total time=   0.6s
# [01:33:01] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 2/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.347, test=0.344) total time=   0.6s
# [01:33:01] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 3/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.6s
# [01:33:02] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 4/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.6s
# [01:33:03] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 5/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.6s
# [01:33:03] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 6/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.6s
# [01:33:04] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 7/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.6s
# [01:33:04] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 8/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.7s
# [01:33:05] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 9/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   3.0s
# [01:33:08] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 10/10] END alpha=0.6166311449827587, booster=gblinear, eta=0.09435223451786234, gamma=0.14749594189297577, lambda=0.9553397653514669, max_delta_step=6, max_depth=6, min_child_weight=14, n_estimators=914, normalize_type=forest, sample_type=weighted, subsample=0.9704780219934188, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.6s
# [01:33:09] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 1/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.811, test=0.859) total time=   0.2s
# [01:33:09] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 2/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.820, test=0.816) total time=   0.2s
# [01:33:09] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 3/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.816, test=0.803) total time=   0.3s
# [01:33:10] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 4/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.814, test=0.822) total time=   0.3s
# [01:33:10] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 5/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.817, test=0.794) total time=   0.2s
# [01:33:10] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 6/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.820, test=0.794) total time=   0.2s
# [01:33:10] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 7/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.817, test=0.828) total time=   0.2s
# [01:33:11] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 8/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.813, test=0.819) total time=   0.3s
# [01:33:11] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 9/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.815, test=0.800) total time=   0.3s
# [01:33:11] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 10/10] END alpha=0.9011701293254727, booster=gbtree, eta=0.04763913288363828, gamma=0.3255684220325574, lambda=0.13220180645707524, max_delta_step=4, max_depth=9, min_child_weight=17, n_estimators=190, normalize_type=tree, sample_type=uniform, subsample=0.03708885101160875, validate_parameters=True;, score=(train=0.811, test=0.803) total time=   0.2s
# [01:33:11] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 1/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.347, test=0.344) total time=   0.2s
# [01:33:12] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 2/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.347, test=0.344) total time=   0.2s
# [01:33:12] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 3/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.2s
# [01:33:12] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 4/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.2s
# [01:33:12] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 5/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.2s
# [01:33:12] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 6/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.2s
# [01:33:13] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 7/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.2s
# [01:33:13] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 8/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.2s
# [01:33:13] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 9/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.2s
# [01:33:13] WARNING: ../src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "normalize_type", "sample_type", "subsample" } are not used.
#
# [CV 10/10] END alpha=0.8054637171373001, booster=gblinear, eta=0.01847884827632721, gamma=0.7941030684949909, lambda=0.04614343090312578, max_delta_step=14, max_depth=77, min_child_weight=6, n_estimators=302, normalize_type=forest, sample_type=uniform, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=   0.2s
# [01:33:14] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 1/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.988) total time=   3.2s
# [01:33:17] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 2/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.972) total time=   5.6s
# [01:33:23] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 3/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.988) total time=   3.2s
# [01:33:26] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 4/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.984) total time=   3.2s
# [01:33:29] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 5/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.988) total time=   5.5s
# [01:33:35] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 6/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.981) total time=   3.2s
# [01:33:38] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 7/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.972) total time=   3.1s
# [01:33:41] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 8/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.988) total time=   5.6s
# [01:33:47] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 9/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.981) total time=   3.3s
# [01:33:50] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
# [CV 10/10] END alpha=0.6527387132297452, booster=gbtree, eta=0.04371256313149228, gamma=0.2884798758204665, lambda=0.17157390697716968, max_delta_step=12, max_depth=16, min_child_weight=4, n_estimators=452, normalize_type=forest, sample_type=weighted, subsample=0.6867406224286962, validate_parameters=True;, score=(train=0.999, test=0.972) total time=   3.3s
# [CV 1/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.314, test=0.316) total time=  13.2s
# [CV 2/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.347, test=0.344) total time=  13.2s
# [CV 3/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=  13.2s
# [CV 4/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=  14.7s
# [CV 5/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=  13.4s
# [CV 6/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=  13.3s
# [CV 7/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.315, test=0.312) total time=  13.2s
# [CV 8/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=  15.6s
# [CV 9/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=  13.3s
# [CV 10/10] END alpha=0.758262681653513, booster=dart, eta=0.09011166851554389, gamma=0.21602086683509047, lambda=0.48178938953411965, max_delta_step=17, max_depth=87, min_child_weight=19, n_estimators=336, normalize_type=forest, sample_type=weighted, subsample=0.010620777471223253, validate_parameters=True;, score=(train=0.346, test=0.347) total time=  13.2s
# [01:36:13] WARNING: ../src/learner.cc:767:
# Parameters: { "normalize_type", "sample_type" } are not used.
#
#
#
# Le tomó 1579.67 segundos para encontrar los parámetros

# %%
# Resultados del entrenamiento

print('Los mejores parámetros para la base de datos desequilibrada:', hiperparametros.best_params_)
print('\n')
print('Índice que le corresponde:', hiperparametros.best_index_)
print('\n')
print('Mejor estimador:', hiperparametros.best_estimator_)
print('\n')
print('Mejor exactitud:', str(round(hiperparametros.best_score_*100, 4)) + '%')
# Out:
# Los mejores parámetros para la base de datos desequilibrada: {'validate_parameters': True, 'subsample': 0.6867406224286962, 'sample_type': 'weighted', 'normalize_type': 'forest', 'n_estimators': 452, 'min_child_weight': 4, 'max_depth': 16, 'max_delta_step': 12, 'lambda': 0.17157390697716968, 'gamma': 0.2884798758204665, 'eta': 0.04371256313149228, 'booster': 'gbtree', 'alpha': 0.6527387132297452}
#
#
# Índice que le corresponde: 8
#
#
# Mejor estimador: XGBClassifier(alpha=0.6527387132297452, base_score=None, booster='gbtree',
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.04371256313149228,
#               eval_metric=None, feature_types=None, gamma=0.2884798758204665,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, lambda=0.17157390697716968,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=12, max_depth=16,
#               max_leaves=None, min_child_weight=4, missing=nan,
#               monotone_constraints=None, n_estimators=452, n_jobs=None, ...)
#
#
# Mejor exactitud: 98.125%

# %%
# Evaluación del modelo

y_predicha = hiperparametros.predict(x_prueba)
print(classification_report(y_prueba, y_predicha, target_names = etiquetas))
matriz_confusion(y_prueba, y_predicha)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.97      0.97       395
#   Sospechoso       0.98      0.97      0.97       474
#   Patológico       0.99      0.99      0.99       503
#
#     accuracy                           0.98      1372
#    macro avg       0.98      0.98      0.98      1372
# weighted avg       0.98      0.98      0.98      1372

# %%
# Curva ROC AUC
etiquetas_clases= ['Normal', 'Sospechoso', 'Patológico']
colores = ['darkgreen', 'darkorange', 'darkred']

# Función para calcular el ROC AUC multiclase (con gráfico)
def multiclass_roc_auc_score(y_prueba, y_predicha, average = 'micro'):
    lb = LabelBinarizer()
    lb.fit(y_prueba)
    y_prueba = lb.transform(y_prueba)
    y_predicha = lb.transform(y_predicha)

    plt.subplots(1,1, figsize = (8, 5))
    for (idx, c_label) in enumerate(etiquetas_clases):
        fpr, tpr, thresholds = roc_curve(y_prueba[:, idx].astype(int), y_predicha[:,idx])
        plt.plot(fpr, tpr, label = '%s (AUC: %0.2f)' % (c_label, auc(fpr, tpr)), color = colores[idx])
    plt.plot(fpr, fpr, linestyle = '--', color = 'black')
    plt.legend()
    plt.title('Gráfico de curva ROC', fontweight = 'bold')
    plt.xlabel('Tasa de Falsos Positivos', fontweight = 'bold')
    plt.ylabel('Tasa de Verdaderos Positivos', fontweight = 'bold')
    plt.show()
    return roc_auc_score(y_prueba, y_predicha, average = average)

print(f'Área bajo la curva: {multiclass_roc_auc_score(y_prueba, y_predicha)*100:.4f}%\n')
# Out:
# Área bajo la curva: 98.3054%

# %%
# Tabla de resultados de hiperparámetros

tabla = pd.DataFrame(hiperparametros.cv_results_).head(3)
tabla
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      30.300713      1.119985         0.056092        0.018584
# 1      23.854228      9.056093         0.042779        0.005496
# 2       2.364474      0.994104         0.006656        0.000265
#
#   param_validate_parameters param_subsample param_sample_type  \
# 0                      True        0.881644          weighted
# 1                      True        0.637147          weighted
# 2                      True        0.845219          weighted
#
#   param_normalize_type param_n_estimators param_min_child_weight  ...  \
# 0               forest                403                      3  ...
# 1               forest                343                     18  ...
# 2               forest                297                      8  ...
#
#   split2_train_score split3_train_score split4_train_score split5_train_score  \
# 0           0.956250           0.957292           0.958681           0.957639
# 1           0.986111           0.986458           0.986458           0.986806
# 2           0.997569           0.997569           0.998264           0.997222
#
#   split6_train_score split7_train_score split8_train_score split9_train_score  \
# 0           0.957986           0.957639           0.959028           0.959375
# 1           0.986806           0.987153           0.984722           0.986806
# 2           0.998611           0.997569           0.998264           0.997569
#
#    mean_train_score  std_train_score
# 0          0.957674         0.001058
# 1          0.986493         0.000649
# 2          0.997743         0.000446
#
# [3 rows x 43 columns]
