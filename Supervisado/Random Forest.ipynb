# %% [markdown]
# **Tareas pendientes**
# - Cambiar tamaño de los ejes, títulos, la paleta de colores de los gráficos
# - En la matriz de correlación poner la variable categórica
# - Preguntar sobre el score óptimo
# - Preguntar sobre el sobremuestreo
# - Preguntar sobre los valores aleatorios
# - Preguntar sobre la curva roc

# %% [markdown]
# #**Conectarse a Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**Librerías**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from time import time
import matplotlib.colors
import matplotlib.patches as patches

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import (classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, auc,
                             ConfusionMatrixDisplay, f1_score, precision_recall_curve, recall_score, precision_score)
from sklearn.feature_selection import SelectKBest, f_classif, VarianceThreshold, chi2, mutual_info_classif
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import scipy
from collections import Counter

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC  
from xgboost import XGBClassifier
from sklearn.decomposition import PCA

# %% [markdown]
# #**Base de datos**

# %% [markdown]
# ##Lectura de base de datos
#
# La columna **fetal_health** tiene como etiquetas 1-Normal, 2-Sospechoso y 3-Patológico.

# %%
# Lectura de la base de datos

base = pd.read_csv('/content/drive/MyDrive/Proyecto de Consultoria/fetal_health.csv')
print('La base de datos tiene', base.shape[0], 'filas y', base.shape[1], 'columnas')
base.reset_index()
base.head()
# Out:
# La base de datos tiene 2126 filas y 22 columnas
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
# Nombre de las columnas

base.columns
# Out:
# Index(['baseline value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %%
# Cambio de nombre a las columnas

base.columns = ['baseline_value', 'accelerations', 'fetal_movement',
                'uterine_contractions', 'light_decelerations', 'severe_decelerations',
                'prolongued_decelerations', 'abnormal_short_tv',
                'mean_value_of_short_tv',
                'percentage_of_time_waltv',
                'mean_value_of_long_tv', 'histogram_width',
                'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
                'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
                'histogram_median', 'histogram_variance', 'histogram_tendency',
                'fetal_health']

aux = base.copy()
base_MRD = base.copy()

# %%
# Conversión de la columna fetal_health a categoríca

base['fetal_health'] = base['fetal_health'].astype('category')

# %%
# Comprobar si hay valores nulos e información de las columnas

# Verifica si hay nulos en la base
#base.isnull().any()

# Suma la cantidad de nulos que hay en la base
base.isnull().sum()
# Out:
# baseline_value                0
# accelerations                 0
# fetal_movement                0
# uterine_contractions          0
# light_decelerations           0
# severe_decelerations          0
# prolongued_decelerations      0
# abnormal_short_tv             0
# mean_value_of_short_tv        0
# percentage_of_time_waltv      0
# mean_value_of_long_tv         0
# histogram_width               0
# histogram_min                 0
# histogram_max                 0
# histogram_number_of_peaks     0
# histogram_number_of_zeroes    0
# histogram_mode                0
# histogram_mean                0
# histogram_median              0
# histogram_variance            0
# histogram_tendency            0
# fetal_health                  0
# dtype: int64

# %%
# Información de la base

base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   baseline_value              2126 non-null   float64
#  1   accelerations               2126 non-null   float64
#  2   fetal_movement              2126 non-null   float64
#  3   uterine_contractions        2126 non-null   float64
#  4   light_decelerations         2126 non-null   float64
#  5   severe_decelerations        2126 non-null   float64
#  6   prolongued_decelerations    2126 non-null   float64
#  7   abnormal_short_tv           2126 non-null   float64
#  8   mean_value_of_short_tv      2126 non-null   float64
#  9   percentage_of_time_waltv    2126 non-null   float64
#  10  mean_value_of_long_tv       2126 non-null   float64
#  11  histogram_width             2126 non-null   float64
#  12  histogram_min               2126 non-null   float64
#  13  histogram_max               2126 non-null   float64
#  14  histogram_number_of_peaks   2126 non-null   float64
#  15  histogram_number_of_zeroes  2126 non-null   float64
#  16  histogram_mode              2126 non-null   float64
#  17  histogram_mean              2126 non-null   float64
#  18  histogram_median            2126 non-null   float64
#  19  histogram_variance          2126 non-null   float64
#  20  histogram_tendency          2126 non-null   float64
#  21  fetal_health                2126 non-null   category
# dtypes: category(1), float64(21)
# memory usage: 351.1 KB

# %% [markdown]
# #Preprocesamiento

# %% [markdown]
# ##Variables de baja varianza

# %%
# Varianza de cada una de las variables

round(np.var(base.iloc[:, :-1]), 2)
# Out:
# baseline_value                  96.80
# accelerations                    0.00
# fetal_movement                   0.00
# uterine_contractions             0.00
# light_decelerations              0.00
# severe_decelerations             0.00
# prolongued_decelerations         0.00
# abnormal_short_tv              295.45
# mean_value_of_short_tv           0.78
# percentage_of_time_waltv       338.29
# mean_value_of_long_tv           31.66
# histogram_width               1516.83
# histogram_min                  873.40
# histogram_max                  321.84
# histogram_number_of_peaks        8.69
# histogram_number_of_zeroes       0.50
# histogram_mode                 268.22
# histogram_mean                 243.05
# histogram_median               209.18
# histogram_variance             839.31
# histogram_tendency               0.37
# dtype: float64

# %%
# Da como resultado aquellas variables que estan por debajo de 0.25 de varianza

varianza = VarianceThreshold(threshold = 1)
varianza.fit(base.iloc[:, :-1])
columnas = [i for i in base.iloc[:, :-1].columns if i not in base.iloc[:, :-1].columns[varianza.get_support()]]
columnas
# Out:
# ['accelerations',
#  'fetal_movement',
#  'uterine_contractions',
#  'light_decelerations',
#  'severe_decelerations',
#  'prolongued_decelerations',
#  'mean_value_of_short_tv',
#  'histogram_number_of_zeroes',
#  'histogram_tendency']

# %%
# Nueva base de datos sin las variables con baja varianza

base = base.drop(columnas, axis = 1)
print('La base de datos tiene', base.shape[0], 'filas y', base.shape[1], 'columnas')
# Out:
# La base de datos tiene 2126 filas y 13 columnas

# %% [markdown]
# ##Sobremuestreo

# %%
# Conteo de las clases antes del sobremuestreo

ContarA = Counter(base.iloc[:, -1])
print('Antes del sobremuestreo:', ContarA)
# Out:
# Antes del sobremuestreo: Counter({1.0: 1655, 2.0: 295, 3.0: 176})

# %%
# Realizar sobremuestreo con la técnica SMOTEENN

copia_base = base.copy()
filas = base.shape[0]
smoteenn = SMOTEENN(sampling_strategy = 'not majority')
base_smoteenn = smoteenn.fit_resample(copia_base.iloc[:, :-1], copia_base.iloc[:, -1])
                                                             
base_sobremuestreo = base_smoteenn[0]
base_sobremuestreo['fetal_health'] = base_smoteenn[1]
                                                             
print('Se agregarón', base_sobremuestreo.shape[0] - filas, 'filas con respecto a las clases minoritarias')
# Out:
# Se agregarón 2426 filas con respecto a las clases minoritarias

# %%
# Conteo de clases después del sobremuestreo

ContarD = Counter(base_sobremuestreo.iloc[:, -1])
print('Después del sobremuestreo:', ContarD)
# Out:
# Después del sobremuestreo: Counter({3.0: 1612, 2.0: 1547, 1.0: 1393})

# %%
# Realiza un gráfico de conteo de las clases de la variable fetal_health

sns.set_style('darkgrid')
sns.color_palette('husl', 9)

plt.figure(figsize = (10, 5))
colores = {1: 'blue', 2: 'orange', 3: 'red'}

a = sns.countplot(x = base_sobremuestreo['fetal_health'],
                  order = base_sobremuestreo['fetal_health'].value_counts(ascending = False).index, edgecolor = 'black',
                  palette = colores, alpha = 0.5)
valores_absolutos = base_sobremuestreo['fetal_health'].value_counts(ascending = False)
valores_relativos = base_sobremuestreo['fetal_health'].value_counts(ascending = False, normalize = True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(valores_absolutos, valores_relativos)]

a.bar_label(container = a.containers[0], labels = lbls, fontweight = 'bold',
            label_type = 'center',
            #padding = 10,
            color = 'black',
            fontsize = 12)
a.set_xticklabels(['Patológico', 'Sospechoso', 'Normal'])

plt.suptitle('Conteo de las clases de la variable fetal_health', fontweight = 'bold', fontsize = 25, color = 'black')
plt.xticks(color = 'black', fontsize = 12)
plt.yticks(color = 'black')
plt.xlabel('Salud fetal', fontweight = 'bold', fontsize = 15, color = 'black', labelpad = 10)
plt.ylabel('Conteo', fontweight = 'bold', fontsize = 15, color = 'black')
plt.subplots_adjust(top = 0.88)

# %% [markdown]
# ##Selección de variables más importantes

# %% [markdown]
# ###Base de datos desequilibrada

# %%
# Realiza la selección de variables de la base desequilibrada
#https://enjoymachinelearning.com/blog/feature-selection-selectkbest-sklearn/

x = base.iloc[:, :-1] 
y = base.iloc[:, -1]

seleccion = SelectKBest(f_classif, k = 'all')
seleccion.fit(x,y)

puntajes = pd.DataFrame(seleccion.scores_)
columnas = pd.DataFrame(x.columns)
variables_puntaje = pd.concat([columnas, puntajes], axis = 1)
variables_puntaje.columns = ['Variables', 'Puntaje'] 

plt.subplots(figsize = (10, 5))
sns.barplot(data = variables_puntaje, x = 'Puntaje', y = 'Variables', edgecolor = 'black',
            saturation = 1, orient = 'h', alpha = 0.5, palette = 'YlGnBu')
plt.vlines(x = 100, ymin = -1, ymax = 12, color = 'red')
plt.suptitle('Base de datos desequilibrada', fontweight = 'bold', fontsize = 25, color = 'black')
plt.subplots_adjust(top = 0.88)
plt.xticks(color = 'black', fontsize = 12)
plt.yticks(color = 'black', fontsize = 12)
plt.xlabel('Puntaje', fontweight = 'bold', fontsize = 16, color = 'black', labelpad = 10)
plt.ylabel('Variables', fontweight = 'bold', fontsize = 16, color = 'black')
# Out:
# Text(0, 0.5, 'Variables')

# %%
# Crea la nueva base de datos con las variables seleccionadas de la base desequilibrada

seleccionarva = variables_puntaje[variables_puntaje['Puntaje'] >= 100] 
seleccionarva = list(seleccionarva['Variables']) 
seleccionarva.append('fetal_health') 

base_nueva = base[seleccionarva]

print('La base de datos desequilibrada nueva tiene', base_nueva.shape[0], 'filas y', base_nueva.shape[1], 'columnas')
# Out:
# La base de datos desequilibrada nueva tiene 2126 filas y 8 columnas

# %% [markdown]
# ###Base de datos equilibrada

# %%
# Realiza la selección de variables de la base equilibrada

x = base_sobremuestreo.iloc[:, :-1] 
y = base_sobremuestreo.iloc[:, -1]

seleccion = SelectKBest(f_classif, k = 'all')
seleccion.fit(x,y)

puntajes = pd.DataFrame(seleccion.scores_)
columnas = pd.DataFrame(x.columns)
variables_puntaje = pd.concat([columnas, puntajes], axis = 1)
variables_puntaje.columns = ['Variables', 'Puntaje'] 

plt.subplots(figsize = (10, 5))
sns.barplot(data = variables_puntaje, x = 'Puntaje', y = 'Variables', edgecolor = 'black',
            saturation = 1, orient = 'h', alpha = 0.5, palette = 'YlGnBu')
plt.vlines(x = 500, ymin = -1, ymax = 12, color = 'red')
plt.suptitle('Base de datos equilibrada', fontweight = 'bold', fontsize = 25, color = 'black')
plt.subplots_adjust(top = 0.88)
plt.xticks(color = 'black', fontsize = 12)
plt.yticks(color = 'black', fontsize = 12)
plt.xlabel('Puntaje', fontweight = 'bold', fontsize = 16, color = 'black', labelpad = 10)
plt.ylabel('Variables', fontweight = 'bold', fontsize = 16, color = 'black')
# Out:
# Text(0, 0.5, 'Variables')

# %%
# Crea la nueva base de datos con las variables seleccionadas de la base equilibrada

seleccionarva = variables_puntaje[variables_puntaje['Puntaje'] >= 500] 
seleccionarva = list(seleccionarva['Variables']) 
seleccionarva.append('fetal_health') 

base_nueva_sobremuestreo = base_sobremuestreo[seleccionarva]

print('La base de datos equilibrada nueva tiene', base_nueva_sobremuestreo.shape[0], 'filas y',
      base_nueva_sobremuestreo.shape[1], 'columnas')
# Out:
# La base de datos equilibrada nueva tiene 4552 filas y 8 columnas

# %% [markdown]
# #Aprendizaje Supervisado

# %% [markdown]
# ##Base de datos desequilibrada

# %% [markdown]
# ###División del conjunto de entrenamiento y prueba

# %%
# Separa la base desequilibrada en entrenamiento y prueba

x_entrena, x_prueba, y_entrena, y_prueba = train_test_split(base_nueva.iloc[:, :-1], base_nueva.iloc[:, -1],
                                                            test_size = 0.3, shuffle = True)
print('La base de datos desequilibrada de entrenamiento tiene', x_entrena.shape[0], 'filas y', x_entrena.shape[1], 'columnas')
print('La base de datos desequilibrada de prueba tiene', x_prueba.shape[0], 'filas y', x_prueba.shape[1], 'columnas')
# Out:
# La base de datos desequilibrada de entrenamiento tiene 1488 filas y 7 columnas
# La base de datos desequilibrada de prueba tiene 638 filas y 7 columnas

# %% [markdown]
# ###Estandarización de los conjuntos de datos

# %%
# Estandariza la base desequilibrada

estandarizar = StandardScaler()
x_entrena = estandarizar.fit_transform(x_entrena) 
x_prueba = estandarizar.transform(x_prueba)

# %% [markdown]
# ###Modelo Random Forest

# %% [markdown]
# ###Entrenamiento, prueba del modelo y reporte de resultados

# %%
# Función para crear una matriz de confusión

#colores = matplotlib.colors.LinearSegmentedColormap.from_list('custom', ['#008B8B', '#E0FFFF', '#FFFFFF'])
#YlGnBu

etiquetas = ['Normal', 'Sospechoso', 'Patológico']

def matriz_confusion(y_prueba, y_predicha):
  conf_mat = confusion_matrix(y_prueba, y_predicha)
  fig, ax = plt.subplots(figsize = (8,6))
  sns.heatmap(conf_mat, annot = True, fmt = 'd',
              xticklabels = etiquetas,
              yticklabels = etiquetas, cmap = 'Blues',
              linecolor = 'black')
  plt.title('Matriz de Confusión', fontweight = 'bold')
  plt.xlabel('Valores predichos', fontweight = 'bold')
  plt.ylabel('Valores reales', fontweight = 'bold')
  plt.show()

# %%
# Evalua el modelo KNN con parámetros predeterminados

ranfo = RandomForestClassifier()
ranfo.fit(x_entrena, y_entrena)
y_predicha = ranfo.predict(x_prueba)
print('Exactitud en la base de datos desequilibrada:', str(round((cross_val_score(ranfo, x_entrena, y_entrena, cv = 10)).mean()*100, 4)) + '%')
print(classification_report(y_prueba, y_predicha, target_names = etiquetas))
matriz_confusion(y_prueba, y_predicha)
# Out:
# Exactitud en la base de datos desequilibrada: 93.816%
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.99      0.97       488
#   Sospechoso       0.91      0.79      0.84       103
#   Patológico       0.93      0.85      0.89        47
#
#     accuracy                           0.94       638
#    macro avg       0.93      0.87      0.90       638
# weighted avg       0.94      0.94      0.94       638

# %% [markdown]
# ###Hiperparámetros: Entrenamiento, prueba del modelo y reporte de resultados

# %%
# Selección de los hiperparámetros de manera aleatoria

#https://jdvelasq.github.io/courses/notebooks/sklearn_model_selection_and_evaluation/1-09_RandomizedSearchCV.html
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/

#scipy.stats.uniform(scale = 1).rvs(size = 1000)
#scipy.stats.randint.rvs(low = 1, high = 100, size=1000)
#scipy.stats.randint.rvs(low = 1, high = 100, size=10)
#error en 'log_loss
#error con estos parametros bootstrap': [True, False], 'oob_score': [True, False]

parametros = {
    'n_estimators': list(np.arange(1, 501, 1)),
    'criterion': ['gini', 'entropy'],
    'max_features': ['sqrt', 'log2', None],
    'warm_start': [True, False],
    'bootstrap': [True, False],
    #'oob_score': [True, False],
    'min_samples_split': scipy.stats.randint.rvs(low = 2, high = 21, size = 20),
    'min_samples_leaf': scipy.stats.randint.rvs(low = 1, high = 21, size = 20)
}

# %%
# Entrenamiento del modelo

hiperparametros = RandomizedSearchCV(estimator = RandomForestClassifier(),
                                     param_distributions = parametros,
                                     n_iter = 10,
                                     cv = 10,
                                     scoring= 'accuracy',
                                     refit = True,
                                     #n_jobs = -1,
                                     return_train_score = True,
                                     verbose = 3)

start = time()
hiperparametros.fit(x_entrena, y_entrena)
print('\n')
print('Le tomó %.2f segundos para encontrar los parámetros'%(time() - start))
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV 1/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.961, test=0.940) total time=   0.8s
# [CV 2/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.961, test=0.919) total time=   0.9s
# [CV 3/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.963, test=0.913) total time=   0.8s
# [CV 4/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.966, test=0.960) total time=   1.1s
# [CV 5/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.963, test=0.919) total time=   1.2s
# [CV 6/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.963, test=0.933) total time=   1.2s
# [CV 7/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.965, test=0.940) total time=   1.6s
# [CV 8/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.966, test=0.926) total time=   1.6s
# [CV 9/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.959, test=0.919) total time=   0.7s
# [CV 10/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=1, min_samples_split=13, n_estimators=126, warm_start=True;, score=(train=0.966, test=0.926) total time=   1.5s
# [CV 1/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.957, test=0.893) total time=   3.5s
# [CV 2/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.965, test=0.919) total time=   2.3s
# [CV 3/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.954, test=0.899) total time=   1.4s
# [CV 4/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.957, test=0.933) total time=   2.1s
# [CV 5/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.960, test=0.886) total time=   2.1s
# [CV 6/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.963, test=0.960) total time=   1.5s
# [CV 7/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.965, test=0.913) total time=   1.4s
# [CV 8/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.960, test=0.886) total time=   1.3s
# [CV 9/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.952, test=0.919) total time=   1.4s
# [CV 10/10] END bootstrap=False, criterion=gini, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=283, warm_start=True;, score=(train=0.962, test=0.919) total time=   1.3s
# [CV 1/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.928, test=0.926) total time=   0.2s
# [CV 2/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.931, test=0.899) total time=   0.2s
# [CV 3/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.934, test=0.866) total time=   0.2s
# [CV 4/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.931, test=0.946) total time=   0.2s
# [CV 5/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.928, test=0.893) total time=   0.2s
# [CV 6/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.923, test=0.913) total time=   0.2s
# [CV 7/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.928, test=0.926) total time=   0.2s
# [CV 8/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.929, test=0.906) total time=   0.2s
# [CV 9/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.923, test=0.892) total time=   0.2s
# [CV 10/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=13, min_samples_split=8, n_estimators=43, warm_start=True;, score=(train=0.929, test=0.912) total time=   0.2s
# [CV 1/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.926, test=0.899) total time=   0.8s
# [CV 2/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.939, test=0.913) total time=   1.1s
# [CV 3/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.936, test=0.852) total time=   1.1s
# [CV 4/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.934, test=0.933) total time=   1.1s
# [CV 5/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.935, test=0.913) total time=   0.8s
# [CV 6/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.928, test=0.906) total time=   0.7s
# [CV 7/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.931, test=0.913) total time=   0.7s
# [CV 8/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.931, test=0.906) total time=   0.7s
# [CV 9/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.931, test=0.905) total time=   0.7s
# [CV 10/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=275, warm_start=True;, score=(train=0.940, test=0.912) total time=   0.7s
# [CV 1/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.931, test=0.893) total time=   0.1s
# [CV 2/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.941, test=0.906) total time=   0.1s
# [CV 3/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.933, test=0.866) total time=   0.1s
# [CV 4/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.931, test=0.940) total time=   0.1s
# [CV 5/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.931, test=0.906) total time=   0.1s
# [CV 6/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.931, test=0.913) total time=   0.1s
# [CV 7/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.930, test=0.913) total time=   0.1s
# [CV 8/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.932, test=0.899) total time=   0.1s
# [CV 9/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.928, test=0.885) total time=   0.1s
# [CV 10/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=49, warm_start=True;, score=(train=0.943, test=0.892) total time=   0.1s
# [CV 1/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.917, test=0.886) total time=   0.6s
# [CV 2/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.927, test=0.906) total time=   0.6s
# [CV 3/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.922, test=0.866) total time=   0.6s
# [CV 4/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.921, test=0.933) total time=   0.6s
# [CV 5/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.915, test=0.886) total time=   0.6s
# [CV 6/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.922, test=0.906) total time=   0.6s
# [CV 7/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.917, test=0.906) total time=   0.9s
# [CV 8/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.920, test=0.899) total time=   0.9s
# [CV 9/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.917, test=0.872) total time=   0.9s
# [CV 10/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=16, n_estimators=238, warm_start=True;, score=(train=0.928, test=0.899) total time=   0.9s
# [CV 1/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.918, test=0.893) total time=   0.8s
# [CV 2/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.922, test=0.906) total time=   0.8s
# [CV 3/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.922, test=0.859) total time=   0.8s
# [CV 4/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.921, test=0.940) total time=   0.8s
# [CV 5/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.920, test=0.886) total time=   0.8s
# [CV 6/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.923, test=0.906) total time=   0.8s
# [CV 7/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.916, test=0.899) total time=   0.8s
# [CV 8/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.920, test=0.906) total time=   0.8s
# [CV 9/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.916, test=0.872) total time=   0.8s
# [CV 10/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=20, min_samples_split=8, n_estimators=331, warm_start=False;, score=(train=0.929, test=0.892) total time=   0.8s
# [CV 1/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.907, test=0.913) total time=   0.6s
# [CV 2/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.908, test=0.906) total time=   0.6s
# [CV 3/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.906, test=0.832) total time=   1.0s
# [CV 4/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.904, test=0.940) total time=   1.0s
# [CV 5/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.913, test=0.886) total time=   0.9s
# [CV 6/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.910, test=0.899) total time=   0.9s
# [CV 7/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.913, test=0.913) total time=   0.6s
# [CV 8/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.916, test=0.899) total time=   0.6s
# [CV 9/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.904, test=0.885) total time=   0.6s
# [CV 10/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=17, min_samples_split=13, n_estimators=173, warm_start=True;, score=(train=0.908, test=0.905) total time=   0.6s
# [CV 1/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.914, test=0.893) total time=   0.5s
# [CV 2/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.922, test=0.899) total time=   0.6s
# [CV 3/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.924, test=0.872) total time=   0.6s
# [CV 4/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.921, test=0.933) total time=   0.6s
# [CV 5/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.919, test=0.899) total time=   0.6s
# [CV 6/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.910, test=0.906) total time=   0.6s
# [CV 7/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.922, test=0.886) total time=   0.6s
# [CV 8/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.920, test=0.899) total time=   0.6s
# [CV 9/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.913, test=0.885) total time=   0.6s
# [CV 10/10] END bootstrap=True, criterion=entropy, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=226, warm_start=True;, score=(train=0.918, test=0.912) total time=   0.6s
# [CV 1/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.935, test=0.886) total time=   1.3s
# [CV 2/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.937, test=0.913) total time=   1.9s
# [CV 3/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.937, test=0.866) total time=   1.9s
# [CV 4/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.934, test=0.933) total time=   1.2s
# [CV 5/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.932, test=0.899) total time=   1.2s
# [CV 6/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.931, test=0.913) total time=   1.2s
# [CV 7/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.931, test=0.919) total time=   1.2s
# [CV 8/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.931, test=0.899) total time=   1.2s
# [CV 9/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.932, test=0.905) total time=   1.2s
# [CV 10/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=473, warm_start=False;, score=(train=0.938, test=0.899) total time=   1.2s
#
#
# Le tomó 91.26 segundos para encontrar los parámetros

# %%
# Resultados del entrenamiento

print('Los mejores parámetros para la base de datos desequilibrada:', hiperparametros.best_params_)
print('\n')
print('Índice que le corresponde:', hiperparametros.best_index_)
print('\n')
print('Mejor estimador:', hiperparametros.best_estimator_)
print('\n')
print('Mejor exactitud:', str(round(hiperparametros.best_score_*100, 4)) + '%')
# Out:
# Los mejores parámetros para la base de datos desequilibrada: {'warm_start': True, 'n_estimators': 126, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'log2', 'criterion': 'entropy', 'bootstrap': True}
#
#
# Índice que le corresponde: 0
#
#
# Mejor estimador: RandomForestClassifier(criterion='entropy', max_features='log2',
#                        min_samples_split=13, n_estimators=126, warm_start=True)
#
#
# Mejor exactitud: 92.9426%

# %%
# Evaluación del modelo

y_predicha = hiperparametros.predict(x_prueba)
print(classification_report(y_prueba, y_predicha, target_names = etiquetas))
matriz_confusion(y_prueba, y_predicha)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.94      0.98      0.96       488
#   Sospechoso       0.91      0.77      0.83       103
#   Patológico       0.93      0.85      0.89        47
#
#     accuracy                           0.94       638
#    macro avg       0.93      0.87      0.89       638
# weighted avg       0.94      0.94      0.94       638

# %%
# Curva ROC AUC

etiquetas_clases= ['Normal', 'Sospechoso', 'Patológico']
colores = ['darkgreen', 'darkorange', 'darkred']

# Función para calcular el ROC AUC multiclase (con gráfico)
def multiclass_roc_auc_score(y_prueba, y_predicha, average = 'micro'):
    lb = LabelBinarizer()
    lb.fit(y_prueba)
    y_prueba = lb.transform(y_prueba)
    y_predicha = lb.transform(y_predicha)

    plt.subplots(1,1, figsize = (8, 5))
    for (idx, c_label) in enumerate(etiquetas_clases):
        fpr, tpr, thresholds = roc_curve(y_prueba[:, idx].astype(int), y_predicha[:,idx])
        plt.plot(fpr, tpr, label = '%s (AUC: %0.2f)' % (c_label, auc(fpr, tpr)), color = colores[idx])
    plt.plot(fpr, fpr, linestyle = '--', color = 'black')
    plt.legend()
    plt.title('Gráfico de curva ROC', fontweight = 'bold')
    plt.xlabel('Tasa de Falsos Positivos', fontweight = 'bold')
    plt.ylabel('Tasa de Verdaderos Positivos', fontweight = 'bold')
    plt.show()
    return roc_auc_score(y_prueba, y_predicha, average = average)

print(f"Área bajo la curva: {multiclass_roc_auc_score(y_prueba, y_predicha)*100:.4f}%\n")
# Out:
# Área bajo la curva: 95.4154%

# %%
# Tabla de resultados de hiperparámetros

tabla = pd.DataFrame(hiperparametros.cv_results_).head(3)
tabla
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.068044      0.300658         0.063250        0.029358
# 1       1.770541      0.612831         0.063537        0.059658
# 2       0.158626      0.006452         0.007630        0.000725
#
#   param_warm_start param_n_estimators param_min_samples_split  \
# 0             True                126                      13
# 1             True                283                       7
# 2             True                 43                       8
#
#   param_min_samples_leaf param_max_features param_criterion  ...  \
# 0                      1               log2         entropy  ...
# 1                      4               None            gini  ...
# 2                     13               None         entropy  ...
#
#   split2_train_score split3_train_score  split4_train_score  \
# 0           0.962659           0.966393            0.962659
# 1           0.953697           0.956684            0.960418
# 2           0.933532           0.931292            0.927558
#
#    split5_train_score  split6_train_score  split7_train_score  \
# 0            0.963406            0.964899            0.966393
# 1            0.963406            0.964899            0.960418
# 2            0.923077            0.928305            0.929052
#
#    split8_train_score  split9_train_score  mean_train_score  std_train_score
# 0            0.958955            0.966418          0.963411         0.002452
# 1            0.952239            0.961940          0.959603         0.004239
# 2            0.923134            0.929104          0.928390         0.003115
#
# [3 rows x 37 columns]

# %% [markdown]
# ##Base de datos equilibrada

# %% [markdown]
# ###División del conjunto de entrenamiento y prueba

# %%
# Separa la base desequilibrada en entrenamiento y prueba

x_entrena, x_prueba, y_entrena, y_prueba = train_test_split(base_nueva_sobremuestreo.iloc[:, :-1], base_nueva_sobremuestreo.iloc[:, -1],
                                                            test_size = 0.3, shuffle = True)
print('La base de datos desequilibrada de entrenamiento tiene', x_entrena.shape[0], 'filas y', x_entrena.shape[1], 'columnas')
print('La base de datos desequilibrada de prueba tiene', x_prueba.shape[0], 'filas y', x_prueba.shape[1], 'columnas')
# Out:
# La base de datos desequilibrada de entrenamiento tiene 3186 filas y 7 columnas
# La base de datos desequilibrada de prueba tiene 1366 filas y 7 columnas

# %% [markdown]
# ###Estandarización de los conjuntos de datos

# %%
# Estandariza la base desequilibrada

estandarizar = StandardScaler()
x_entrena = estandarizar.fit_transform(x_entrena) 
x_prueba = estandarizar.transform(x_prueba)

# %% [markdown]
# ###Modelo Random Forest

# %% [markdown]
# ###Entrenamiento, prueba del modelo y reporte de resultados

# %%
# Función para crear una matriz de confusión

#colores = matplotlib.colors.LinearSegmentedColormap.from_list('custom', ['#008B8B', '#E0FFFF', '#FFFFFF'])
#YlGnBu

etiquetas = ['Normal', 'Sospechoso', 'Patológico']

def matriz_confusion(y_prueba, y_predicha):
  conf_mat = confusion_matrix(y_prueba, y_predicha)
  fig, ax = plt.subplots(figsize = (8,6))
  sns.heatmap(conf_mat, annot = True, fmt = 'd',
              xticklabels = etiquetas,
              yticklabels = etiquetas, cmap = 'Blues',
              linecolor = 'black')
  plt.title('Matriz de Confusión', fontweight = 'bold')
  plt.xlabel('Valores predichos', fontweight = 'bold')
  plt.ylabel('Valores reales', fontweight = 'bold')
  plt.show()

# %%
# Evalua el modelo KNN con parámetros predeterminados

ranfo = RandomForestClassifier()
ranfo.fit(x_entrena, y_entrena)
y_predicha = ranfo.predict(x_prueba)
print('Exactitud en la base de datos desequilibrada:', str(round((cross_val_score(ranfo, x_entrena, y_entrena, cv = 10)).mean()*100, 4)) + '%')
print(classification_report(y_prueba, y_predicha, target_names = etiquetas))
matriz_confusion(y_prueba, y_predicha)
# Out:
# Exactitud en la base de datos desequilibrada: 96.6415%
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.98      0.98       428
#   Sospechoso       0.96      0.97      0.97       471
#   Patológico       0.98      0.98      0.98       467
#
#     accuracy                           0.98      1366
#    macro avg       0.98      0.98      0.98      1366
# weighted avg       0.98      0.98      0.98      1366

# %% [markdown]
# ###Hiperparámetros: Entrenamiento, prueba del modelo y reporte de resultados

# %%
# Selección de los hiperparámetros de manera aleatoria

#https://jdvelasq.github.io/courses/notebooks/sklearn_model_selection_and_evaluation/1-09_RandomizedSearchCV.html
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/

#scipy.stats.uniform(scale = 1).rvs(size = 1000)
#scipy.stats.randint.rvs(low = 1, high = 100, size=1000)
#scipy.stats.randint.rvs(low = 1, high = 100, size=10)
#solo 2 dimensiones 'haversine'

parametros = {
    'n_estimators': list(np.arange(1, 501, 1)),
    'criterion': ['gini', 'entropy'],
    'max_features': ['sqrt', 'log2', None],
    'warm_start': [True, False],
    'bootstrap': [True, False],
    #'oob_score': [True, False],
    'min_samples_split': scipy.stats.randint.rvs(low = 2, high = 21, size = 20),
    'min_samples_leaf': scipy.stats.randint.rvs(low = 1, high = 21, size = 20)
}

# %%
# Entrenamiento del modelo

hiperparametros = RandomizedSearchCV(estimator = RandomForestClassifier(),
                                     param_distributions = parametros,
                                     n_iter = 10,
                                     cv = 10,
                                     scoring= 'accuracy',
                                     refit = True,
                                     #n_jobs = -1,
                                     return_train_score = True,
                                     verbose = 3)

start = time()
hiperparametros.fit(x_entrena, y_entrena)
print('\n')
print('Le tomó %.2f segundos para encontrar los parámetros'%(time() - start))
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV 1/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.958, test=0.931) total time=   2.8s
# [CV 2/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.963, test=0.947) total time=   7.2s
# [CV 3/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.961, test=0.947) total time=   3.7s
# [CV 4/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.962, test=0.918) total time=   3.1s
# [CV 5/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.963, test=0.915) total time=   3.1s
# [CV 6/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.959, test=0.922) total time=   1.9s
# [CV 7/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.963, test=0.940) total time=   1.4s
# [CV 8/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.959, test=0.937) total time=   1.4s
# [CV 9/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.961, test=0.947) total time=   1.3s
# [CV 10/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=223, warm_start=False;, score=(train=0.960, test=0.943) total time=   1.4s
# [CV 1/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.967, test=0.934) total time=   0.7s
# [CV 2/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.965, test=0.922) total time=   0.7s
# [CV 3/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.971, test=0.925) total time=   0.6s
# [CV 4/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.965, test=0.922) total time=   0.7s
# [CV 5/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.964, test=0.934) total time=   0.7s
# [CV 6/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.966, test=0.915) total time=   0.8s
# [CV 7/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.964, test=0.921) total time=   1.0s
# [CV 8/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.963, test=0.943) total time=   1.0s
# [CV 9/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.962, test=0.956) total time=   1.0s
# [CV 10/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=37, warm_start=True;, score=(train=0.963, test=0.903) total time=   0.9s
# [CV 1/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.961, test=0.947) total time=   0.6s
# [CV 2/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.962, test=0.956) total time=   0.7s
# [CV 3/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.958, test=0.947) total time=   0.6s
# [CV 4/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.962, test=0.925) total time=   0.6s
# [CV 5/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.959, test=0.915) total time=   0.6s
# [CV 6/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.961, test=0.922) total time=   0.6s
# [CV 7/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.958, test=0.937) total time=   0.7s
# [CV 8/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.961, test=0.937) total time=   0.7s
# [CV 9/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.963, test=0.940) total time=   0.6s
# [CV 10/10] END bootstrap=False, criterion=gini, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=119, warm_start=False;, score=(train=0.956, test=0.934) total time=   0.6s
# [CV 1/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.937, test=0.928) total time=   1.9s
# [CV 2/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.939, test=0.937) total time=   2.6s
# [CV 3/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.939, test=0.928) total time=   3.0s
# [CV 4/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.943, test=0.922) total time=   1.9s
# [CV 5/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.943, test=0.909) total time=   1.6s
# [CV 6/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.944, test=0.897) total time=   1.6s
# [CV 7/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.940, test=0.912) total time=   1.6s
# [CV 8/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.941, test=0.925) total time=   1.6s
# [CV 9/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.940, test=0.950) total time=   1.6s
# [CV 10/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=378, warm_start=False;, score=(train=0.941, test=0.925) total time=   2.4s
# [CV 1/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.977, test=0.956) total time=   2.0s
# [CV 2/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.979, test=0.972) total time=   1.5s
# [CV 3/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.980, test=0.950) total time=   1.5s
# [CV 4/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.978, test=0.931) total time=   1.5s
# [CV 5/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.978, test=0.931) total time=   1.5s
# [CV 6/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.977, test=0.934) total time=   1.4s
# [CV 7/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.980, test=0.953) total time=   1.6s
# [CV 8/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.979, test=0.947) total time=   2.3s
# [CV 9/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.979, test=0.950) total time=   1.9s
# [CV 10/10] END bootstrap=True, criterion=gini, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=326, warm_start=True;, score=(train=0.976, test=0.962) total time=   1.5s
# [CV 1/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.963, test=0.947) total time=   2.1s
# [CV 2/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.964, test=0.953) total time=   2.1s
# [CV 3/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.963, test=0.950) total time=   2.2s
# [CV 4/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.965, test=0.925) total time=   2.8s
# [CV 5/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.963, test=0.918) total time=   2.7s
# [CV 6/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.962, test=0.918) total time=   2.1s
# [CV 7/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.965, test=0.937) total time=   2.1s
# [CV 8/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.964, test=0.940) total time=   2.1s
# [CV 9/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.964, test=0.940) total time=   2.1s
# [CV 10/10] END bootstrap=False, criterion=gini, max_features=log2, min_samples_leaf=16, min_samples_split=9, n_estimators=392, warm_start=True;, score=(train=0.960, test=0.937) total time=   3.2s
# [CV 1/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.979, test=0.953) total time=   2.4s
# [CV 2/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.977, test=0.959) total time=   2.2s
# [CV 3/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.979, test=0.947) total time=   2.4s
# [CV 4/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.980, test=0.944) total time=   2.3s
# [CV 5/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.979, test=0.944) total time=   2.8s
# [CV 6/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.980, test=0.931) total time=   2.9s
# [CV 7/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.982, test=0.937) total time=   2.2s
# [CV 8/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.977, test=0.953) total time=   2.3s
# [CV 9/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.979, test=0.965) total time=   2.2s
# [CV 10/10] END bootstrap=True, criterion=entropy, max_features=None, min_samples_leaf=6, min_samples_split=12, n_estimators=184, warm_start=False;, score=(train=0.978, test=0.959) total time=   2.2s
# [CV 1/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.982, test=0.966) total time=   1.2s
# [CV 2/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.983, test=0.962) total time=   1.2s
# [CV 3/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.981, test=0.950) total time=   1.2s
# [CV 4/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.984, test=0.937) total time=   0.9s
# [CV 5/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.980, test=0.947) total time=   0.8s
# [CV 6/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.982, test=0.950) total time=   0.8s
# [CV 7/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.985, test=0.956) total time=   0.8s
# [CV 8/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.979, test=0.956) total time=   0.8s
# [CV 9/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.982, test=0.953) total time=   0.8s
# [CV 10/10] END bootstrap=False, criterion=entropy, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=118, warm_start=False;, score=(train=0.979, test=0.959) total time=   0.8s
# [CV 1/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.997, test=0.944) total time=   2.0s
# [CV 2/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.998, test=0.950) total time=   2.2s
# [CV 3/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.997, test=0.944) total time=   2.9s
# [CV 4/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.998, test=0.944) total time=   2.5s
# [CV 5/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.998, test=0.947) total time=   2.1s
# [CV 6/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.998, test=0.944) total time=   2.5s
# [CV 7/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.998, test=0.943) total time=   2.5s
# [CV 8/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.998, test=0.947) total time=   2.2s
# [CV 9/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.998, test=0.969) total time=   3.0s
# [CV 10/10] END bootstrap=False, criterion=entropy, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=110, warm_start=True;, score=(train=0.997, test=0.934) total time=   2.4s
# [CV 1/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.955, test=0.931) total time=   0.4s
# [CV 2/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.952, test=0.937) total time=   0.3s
# [CV 3/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.955, test=0.931) total time=   0.4s
# [CV 4/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.956, test=0.912) total time=   0.3s
# [CV 5/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.956, test=0.915) total time=   0.3s
# [CV 6/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.959, test=0.906) total time=   0.4s
# [CV 7/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.963, test=0.934) total time=   0.3s
# [CV 8/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.955, test=0.937) total time=   0.4s
# [CV 9/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.954, test=0.931) total time=   0.3s
# [CV 10/10] END bootstrap=True, criterion=gini, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=36, warm_start=True;, score=(train=0.953, test=0.950) total time=   0.3s
#
#
# Le tomó 174.15 segundos para encontrar los parámetros

# %%
# Resultados del entrenamiento

print('Los mejores parámetros para la base de datos desequilibrada:', hiperparametros.best_params_)
print('\n')
print('Índice que le corresponde:', hiperparametros.best_index_)
print('\n')
print('Mejor estimador:', hiperparametros.best_estimator_)
print('\n')
print('Mejor exactitud:', str(round(hiperparametros.best_score_*100, 4)) + '%')
# Out:
# Los mejores parámetros para la base de datos desequilibrada: {'warm_start': False, 'n_estimators': 118, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'criterion': 'entropy', 'bootstrap': False}
#
#
# Índice que le corresponde: 7
#
#
# Mejor estimador: RandomForestClassifier(bootstrap=False, criterion='entropy',
#                        max_features='log2', min_samples_leaf=10,
#                        min_samples_split=10, n_estimators=118)
#
#
# Mejor exactitud: 95.355%

# %%
# Evaluación del modelo

y_predicha = hiperparametros.predict(x_prueba)
print(classification_report(y_prueba, y_predicha, target_names = etiquetas))
matriz_confusion(y_prueba, y_predicha)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.97      0.97       428
#   Sospechoso       0.94      0.94      0.94       471
#   Patológico       0.96      0.96      0.96       467
#
#     accuracy                           0.96      1366
#    macro avg       0.96      0.96      0.96      1366
# weighted avg       0.96      0.96      0.96      1366

# %%
# Curva ROC AUC
etiquetas_clases= ['Normal', 'Sospechoso', 'Patológico']
colores = ['darkgreen', 'darkorange', 'darkred']

# Función para calcular el ROC AUC multiclase (con gráfico)
def multiclass_roc_auc_score(y_prueba, y_predicha, average = 'micro'):
    lb = LabelBinarizer()
    lb.fit(y_prueba)
    y_prueba = lb.transform(y_prueba)
    y_predicha = lb.transform(y_predicha)

    plt.subplots(1,1, figsize = (8, 5))
    for (idx, c_label) in enumerate(etiquetas_clases):
        fpr, tpr, thresholds = roc_curve(y_prueba[:, idx].astype(int), y_predicha[:,idx])
        plt.plot(fpr, tpr, label = '%s (AUC: %0.2f)' % (c_label, auc(fpr, tpr)), color = colores[idx])
    plt.plot(fpr, fpr, linestyle = '--', color = 'black')
    plt.legend()
    plt.title('Gráfico de curva ROC', fontweight = 'bold')
    plt.xlabel('Tasa de Falsos Positivos', fontweight = 'bold')
    plt.ylabel('Tasa de Verdaderos Positivos', fontweight = 'bold')
    plt.show()
    return roc_auc_score(y_prueba, y_predicha, average = average)

print(f"Área bajo la curva: {multiclass_roc_auc_score(y_prueba, y_predicha)*100:.4f}%\n")
# Out:
# Área bajo la curva: 96.7057%

# %%
# Tabla de resultados de hiperparámetros

tabla = pd.DataFrame(hiperparametros.cv_results_).head(3)
tabla
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.665195      1.676531         0.074120        0.045457
# 1       0.791641      0.144800         0.009011        0.001749
# 2       0.621260      0.012901         0.022145        0.002535
#
#   param_warm_start param_n_estimators param_min_samples_split  \
# 0            False                223                      18
# 1             True                 37                       4
# 2            False                119                       9
#
#   param_min_samples_leaf param_max_features param_criterion  ...  \
# 0                     19               log2         entropy  ...
# 1                      7               None         entropy  ...
# 2                     17               sqrt            gini  ...
#
#   split2_train_score split3_train_score  split4_train_score  \
# 0           0.960935           0.962330            0.963376
# 1           0.970701           0.965120            0.964074
# 2           0.957796           0.961981            0.958842
#
#    split5_train_score  split6_train_score  split7_train_score  \
# 0            0.959191            0.963389            0.959205
# 1            0.965818            0.964435            0.963040
# 2            0.960935            0.958159            0.961297
#
#    split8_train_score  split9_train_score  mean_train_score  std_train_score
# 0            0.960948            0.959554          0.960975         0.001900
# 1            0.961994            0.963389          0.965021         0.002283
# 2            0.962692            0.956416          0.960103         0.002021
#
# [3 rows x 37 columns]
